# %% [markdown]
# <a href="https://colab.research.google.com/github/virajvaidya/SRC_ANU_Sampling_1/blob/main/HomeworkW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![hww1.png](data:image/png;base64,...)

# %% [markdown]
# ![hww12.png](data:image/png;base64,...)

# %%
import statistics as st
import itertools as it

# %%
pop = [5,1,4,10,7]

# %%
popmean = st.mean(pop)
print("The population mean is :", popmean)
# Out:
# The population mean is : 5.4

# %% [markdown]
# # The population mean ̅Y is 5.4.

# %%
popvar = st.pvariance(pop)
print("The population variance is :", popvar)
# Out:
# The population variance is : 9.04

# %% [markdown]
# # The population sample variance S^2 = 9.04

# %% [markdown]
# ![hww14.png](data:image/png;base64,...)

# %%
comb3 = list(it.combinations(pop,3))
print(comb3)
# Out:
# [(5, 1, 4), (5, 1, 10), (5, 1, 7), (5, 4, 10), (5, 4, 7), (5, 10, 7), (1, 4, 10), (1, 4, 7), (1, 10, 7), (4, 10, 7)]

# %% [markdown]
# ![hww16.png](data:image/png;base64,...)

# %%
print("Combination | Sample Mean | Sample Variance")
print("-------------------------------------------")
for comb in comb3:
    sampmean = sum(comb) / len(comb)
    sampvar = st.variance(comb)
    print(f"{comb} | {sampmean:.2f} | {sampvar:.2f}")
# Out:
# Combination | Sample Mean | Sample Variance
# -------------------------------------------
# (5, 1, 4) | 3.33 | 4.33
# (5, 1, 10) | 5.33 | 20.33
# (5, 1, 7) | 4.33 | 9.33
# (5, 4, 10) | 6.33 | 10.33
# (5, 4, 7) | 5.33 | 2.33
# (5, 10, 7) | 7.33 | 6.33
# (1, 4, 10) | 5.00 | 21.00
# (1, 4, 7) | 4.00 | 9.00
# (1, 10, 7) | 6.00 | 21.00
# (4, 10, 7) | 7.00 | 9.00

# %% [markdown]
# # Population mean was 5.4 and the population variance was 9.04. So no, none of the sample means or element variances are equal to thir corresponding population parameters.

# %% [markdown]
# ![hww17.png](data:image/png;base64,...)

# %%
sampmeanlist = [3.33, 5.33, 4.33, 6.33, 5.33, 7.33, 5.00, 4.00, 6.00, 7.00]
sampvarlist = [4.33, 20.33, 9.33, 10.33, 2.33, 6.33, 21.00, 9.00, 21.00, 9.00]
avgmean = st.mean(sampmeanlist)
avgvar = st.mean(sampvarlist)

print("The average of the sample means is :", avgmean)
print("The average of the element variances is :", avgvar)
# Out:
# The average of the sample means is : 5.398
# The average of the element variances is : 11.298

# %% [markdown]
# # The average of the sample means is 5.398, which is the same as the population mean 5.4. The average of the element variances is 11.298 which is not the same as the population variance of 9.04.

# %% [markdown]
# ![hww1final.png](data:image/png;base64,...)

# %% [markdown]
# # Answer (a) 01:30
#
#
#
#
#
# # Answer (b) 3/10
